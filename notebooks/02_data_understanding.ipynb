# %% [markdown]
# # 📊 02 - Data Understanding
#
# **Aktivitas:**
# - Eksplorasi dataset medis awal.
# - Analisis distribusi biaya dan profil pasien.
# - Identifikasi masalah kualitas data (missing values/outliers).
