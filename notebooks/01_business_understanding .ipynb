# %% [markdown]
# # 🏥 01 - Business Understanding
#
# **Tujuan Proyek:** Mengembangkan sistem deteksi anomali pada biaya layanan kesehatan.
#
# **Output Utama:** Definisi KPI untuk deteksi anomali biaya medis.
