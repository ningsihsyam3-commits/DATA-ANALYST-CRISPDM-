# %% [markdown]
# # 🧪 03 - Data Preparation
#
# **Aktivitas:**
# - Cleaning data menggunakan Pandas.
# - Integrasi data ke SQLite menggunakan SQLAlchemy.
# - Normalisasi fitur biaya layanan kesehatan.
